# %% [markdown]
# [10]
# 根结点 1键

# %% [markdown]
# [10,20]
# 根结点 2键

# %% [markdown]
# [5,10,20]   (3 键，超限)
#
# 中间键 10 上升为新根
# 左节点 [5]，右节点 [20]
#
#     [10]
#    /    \
# [5]     [20]

# %% [markdown]
#     [10]
#    /    \
# [5,6]    [20]

# %% [markdown]
#     [10]
#    /    \
# [5,6]   [12,20]

# %% [markdown]
#     [10]
#    /    \
# [5,6]   [12,20,30]
#
#     [10,20]
#    /   |   \
# [5,6] [12] [30]

# %% [markdown]
#     [10,20]   键值：10, 20；孩子数：3
#     /  |   \
# [5,6] [12] [25,30]
#
# 键值：5,6；孩子数：0
# 键值：12；孩子数：0
# 键值：25,30；孩子数：0

# %% [markdown]
# 验证 B-Tree 性质
#
# 根节点：2个键值，3个孩子
# 左叶子：2个键值，0个孩子
# 中叶：1个键值，0个孩子
# 最大键数<3和最大孩子数<=3
#
# 根结点有3个孩子
#
# 无非根非叶结点（无需检查）
#
# 所有叶子同层深度均为2
