# %% [markdown]
# 30(bf=0)
# 无失衡

# %% [markdown]
#   30(bf=1)
#   /
# 20(bf=0)
# 无失衡

# %% [markdown]
#     30(bf=2)   ← 失衡
#    /
#  20(bf=1)
#  /
# 10(bf=0)
#
# 失衡类型：LL
# 旋转轴：结点30作为轴，右旋
#     20(bf=0)
#    /     \
# 10(bf=0) 30(bf=0)

# %% [markdown]
#     20(bf=-1)
#    /     \
# 10(bf=0) 30(bf=1)
#          /
#         25(bf=0)
# 无失衡

# %% [markdown]
#     20(bf=-1)
#    /     \
# 10(bf=0) 30(bf=0)
#         /    \
#     25(bf=0) 40(bf=0)
# 无失衡

# %% [markdown]
#     20(bf=-2)
#    /     \
# 10(bf=0) 30(bf=-1)
#         /    \
#     25(bf=0) 40(bf=1)
#             /
#         35(bf=0)
#
# 失衡类型:RR
# 旋转轴：结点20作为轴，左旋
#             30(bf=1)
#            /        \
#     20(bf=0)         40(bf=-1)
#     /    \          /
# 10(bf=0) 25(bf=0)  35(bf=0)

# %% [markdown]
#              30(bf=1)
#            /          \
#     20(bf=0)          40(bf=-1)
#     /    \           /
# 10(bf=0) 25(bf=0)  35(bf=0)

# %% [markdown]
#              30(bf=1)
#            /          \
#     20(bf=0)          40(bf=-1)
#     /    \           /        \
# 10(bf=0) 25(bf=0)  35(bf=0)   50(bf=0)
#
# 中序遍历：10 → 20 → 25 → 30 → 35 → 40 → 50
